# %% [markdown]
# ## Fine-tuning CNN for AI-generated Image Detection
# In this notebook, we will explore the task of classifying images as real or AI-generated using fine-tuning techniques with several well-known CNN architectures. For this classification task, we will use the CIFAKE dataset, which includes both real and AI-generated images.
#
# Link for the dataset: [CIFAKE: Real and AI-Generated Synthetic Images](https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images)

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from IPython.display import Image

# %%
train_dataset_dir = "D:/MS/Term6/462/Project/Data/train"
test_dataset_dir = "D:/MS/Term6/462/Project/Data/test"
print("Loading dataset from: " + dataset_dir)
# Out:
# Loading dataset from: D:/MS/Term6/462/Project/Data/train

# %%
img_height = 32
img_width = 32
batch_size = 500

# Load the training data
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_dir,
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

# Load the validation data
val_ds = tf.keras.utils.image_dataset_from_directory(
  test_dataset_dir ,
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

print("Training Classes:")
class_names = train_ds.class_names
print(class_names)

print("Testing Classes:")
class_names = val_ds.class_names
print(class_names)
# Out:
# Found 100000 files belonging to 2 classes.
# Found 20000 files belonging to 2 classes.
# Training Classes:
# ['FAKE', 'REAL']
# Testing Classes:
# ['FAKE', 'REAL']

# %% [markdown]
# Larger batch sizes are expected to result in significantly longer training times, especially with a substantial training set of 100,000 images. However, the compact size of the images effectively reduces the impact on training duration.

# %%
# Function for plotting the error rate and metrics rate
def plot_metrics(history, metric):
    plt.plot(history.history[metric], label = metric)
    plt.plot(history.history['val_' + metric], label='val_' + metric)
    plt.xlabel('Epochs')
    plt.ylabel(metric)
    plt.legend()
    plt.show()
    
# Constant values that will be shared by all the models
val_true_classes = np.concatenate([y for x, y in val_ds], axis = 0)  # Get true labels
class_names = ['FAKE', 'REAL']
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True)

# %% [markdown]
# ### Model Building
#
# All the models share the same architecture for a fair comparison: the input layer, followed by the base model with pre-trained weights from the imagenet, then a few dense layers, and then a unit output with a sigmoid activation function.
#
# Training is conducted with early stopping criteria monitoring the validation loss, and the best weights will be restored once the training is completed.

# %%
# Building the Transfer Learning model using ResNet50
ResNet_base_model = tf.keras.applications.ResNet50(
    include_top = False, 
    weights = 'imagenet', 
    input_shape = (img_height, img_width, 3),
    pooling = 'max'
)
ResNet_base_model.trainable = True

# Create a new model on top of the ResNet50 base
inputs = tf.keras.Input(shape = (img_height, img_width, 3))
x = ResNet_base_model(inputs, training = False)
x = BatchNormalization(axis = -1, momentum = 0.99, epsilon = 0.001)(x)
x = Dense(256, 
          kernel_regularizer = regularizers.l2(0.01), 
          activity_regularizer = regularizers.l1(0.01), 
          bias_regularizer = regularizers.l1(0.01),
          activation = 'relu')(x)
x = Dropout(rate = .4, seed = 512)(x)       
x = Dense(64, activation = 'relu')(x)
outputs = Dense(1, activation = 'sigmoid')(x)
ResNet_model = tf.keras.Model(inputs, outputs)

# Compile the model
ResNet_model.compile(
    optimizer = tf.keras.optimizers.Adamax(learning_rate = .001),
    loss = tf.keras.losses.BinaryCrossentropy(),
    metrics = ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

# Summary of the model
ResNet_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ resnet50 (Functional)                │ (None, 2048)                │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 2048)                │           8,192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         524,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 24,136,961 (92.08 MB)
#  Trainable params: 24,079,745 (91.86 MB)
#  Non-trainable params: 57,216 (223.50 KB)

# %%
# Train the Transfer Learning model
print("Starting training with Transfer Learning using ResNet50...")
ResNet_model_history = ResNet_model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 20,
    verbose = 1,
    callbacks = [early_stopping]
)
print("Transfer Learning training finished.")
# Out:
# Starting training with Transfer Learning using ResNet50...
# Epoch 1/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 834s 4s/step - accuracy: 0.4996 - loss: 2.4757 - precision: 0.4999 - recall: 0.8793 - val_accuracy: 0.5005 - val_loss: 3.9000 - val_precision: 0.5003 - val_recall: 0.9996
# Epoch 2/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 781s 4s/step - accuracy: 0.5007 - loss: 2.3564 - precision: 0.5007 - recall: 0.7157 - val_accuracy: 0.4985 - val_loss: 8.3776 - val_precision: 0.3214 - val_recall: 0.0027
# Epoch 3/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 766s 4s/step - accuracy: 0.4966 - loss: 2.2379 - precision: 0.4535 - recall: 0.3208 - val_accuracy: 0.4992 - val_loss: 3.5933 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 788s 4s/step - accuracy: 0.4983 - loss: 2.1363 - precision: 0.4785 - recall: 0.5483 - val_accuracy: 0.5001 - val_loss: 2.1535 - val_precision: 0.6667 - val_recall: 2.0000e-04
# Epoch 5/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 825s 4s/step - accuracy: 0.4956 - loss: 2.0573 - precision: 0.5001 - recall: 0.4563 - val_accuracy: 0.5001 - val_loss: 1.9730 - val_precision: 0.5001 - val_recall: 1.0000
# Epoch 6/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 773s 4s/step - accuracy: 0.5011 - loss: 1.9452 - precision: 0.5010 - recall: 0.6597 - val_accuracy: 0.5013 - val_loss: 24.6819 - val_precision: 0.5006 - val_recall: 0.9957
# Epoch 7/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 763s 4s/step - accuracy: 0.4997 - loss: 1.8475 - precision: 0.4997 - recall: 0.7070 - val_accuracy: 0.5001 - val_loss: 3.2599 - val_precision: 0.5001 - val_recall: 0.9999
# Epoch 8/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 765s 4s/step - accuracy: 0.5005 - loss: 1.7499 - precision: 0.5003 - recall: 0.5903 - val_accuracy: 0.4969 - val_loss: 1.7985 - val_precision: 0.4984 - val_recall: 0.9923
# Epoch 9/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 775s 4s/step - accuracy: 0.4989 - loss: 1.6785 - precision: 0.4995 - recall: 0.6369 - val_accuracy: 0.4993 - val_loss: 2.7839 - val_precision: 0.4996 - val_recall: 0.9953
# Epoch 10/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 830s 4s/step - accuracy: 0.5013 - loss: 1.5715 - precision: 0.5009 - recall: 0.6418 - val_accuracy: 0.5003 - val_loss: 1.5482 - val_precision: 0.5002 - val_recall: 0.9998
# Epoch 11/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 868s 4s/step - accuracy: 0.5010 - loss: 1.4786 - precision: 0.5008 - recall: 0.6977 - val_accuracy: 0.5001 - val_loss: 1.4186 - val_precision: 0.5000 - val_recall: 0.9999
# Epoch 12/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1006s 5s/step - accuracy: 0.4994 - loss: 1.4035 - precision: 0.4995 - recall: 0.7200 - val_accuracy: 0.5009 - val_loss: 1.7101 - val_precision: 0.5005 - val_recall: 0.9986
# Epoch 13/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 863s 4s/step - accuracy: 0.4998 - loss: 1.3534 - precision: 0.5002 - recall: 0.6395 - val_accuracy: 0.4995 - val_loss: 1.2850 - val_precision: 0.2500 - val_recall: 5.0000e-04
# Epoch 14/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 786s 4s/step - accuracy: 0.4990 - loss: 1.3025 - precision: 0.4976 - recall: 0.7213 - val_accuracy: 0.5002 - val_loss: 1.4786 - val_precision: 0.5001 - val_recall: 0.9997
# Epoch 15/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 781s 4s/step - accuracy: 0.5004 - loss: 1.2213 - precision: 0.5002 - recall: 0.6740 - val_accuracy: 0.5026 - val_loss: 1.1894 - val_precision: 0.5013 - val_recall: 0.9962
# Epoch 16/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 773s 4s/step - accuracy: 0.5011 - loss: 1.1736 - precision: 0.5009 - recall: 0.7296 - val_accuracy: 0.5001 - val_loss: 3.5611 - val_precision: 0.5001 - val_recall: 0.9979
# Epoch 17/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 780s 4s/step - accuracy: 0.5009 - loss: 1.1316 - precision: 0.5008 - recall: 0.8167 - val_accuracy: 0.5025 - val_loss: 8.0845 - val_precision: 0.5013 - val_recall: 0.9757
# Epoch 18/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 781s 4s/step - accuracy: 0.5013 - loss: 1.0865 - precision: 0.5012 - recall: 0.7506 - val_accuracy: 0.5001 - val_loss: 1.0782 - val_precision: 0.5000 - val_recall: 0.9999
# Epoch 19/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 806s 4s/step - accuracy: 0.5000 - loss: 1.0510 - precision: 0.4998 - recall: 0.6040 - val_accuracy: 0.5002 - val_loss: 1.1024 - val_precision: 0.5517 - val_recall: 0.0016
# Epoch 20/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 787s 4s/step - accuracy: 0.4974 - loss: 1.0146 - precision: 0.4466 - recall: 0.3070 - val_accuracy: 0.4945 - val_loss: 1.8965 - val_precision: 0.4972 - val_recall: 0.9881
# Transfer Learning training finished.

# %%
ResNet_model.save('restnet_model_h5.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow import keras
ResNet_model.save("restnet_model_vivek.keras")

# %%
# Evaluate the model on the test dataset
val_loss, val_accuracy, val_precision, val_recall = ResNet_model.evaluate(val_ds)
# Print the metrics
print(f"Val Loss: {val_loss:.4f}")
print(f"Val Accuracy: {val_accuracy:.4f}")
print(f"Val Precision: {val_precision:.4f}")
print(f"Val Recall: {val_recall:.4f}")
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 24s 600ms/step - accuracy: 0.5049 - loss: 1.0781 - precision: 0.5049 - recall: 0.9998
# Val Loss: 1.0782
# Val Accuracy: 0.5001
# Val Precision: 0.5000
# Val Recall: 0.9999

# %%
# Plot error rates and metric rates
plot_metrics(ResNet_model_history, 'loss')
plot_metrics(ResNet_model_history, 'accuracy')
plot_metrics(ResNet_model_history, 'precision')
plot_metrics(ResNet_model_history, 'recall')
