# %% [markdown]
# ## Fine-tuning CNN for AI-generated Image Detection
# In this notebook, we will explore the task of classifying images as real or AI-generated using fine-tuning techniques with several well-known CNN architectures. For this classification task, we will use the CIFAKE dataset, which includes both real and AI-generated images.
#
# Link for the dataset: [CIFAKE: Real and AI-Generated Synthetic Images](https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images)

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from IPython.display import Image

# %%
train_dataset_dir = "D:/MS/Term6/462/Project/Data/train"
test_dataset_dir = "D:/MS/Term6/462/Project/Data/test"
print("Loading dataset from: " + dataset_dir)
# Out:
# Loading dataset from: D:/MS/Term6/462/Project/Data/train

# %%
img_height = 32
img_width = 32
batch_size = 500

# Load the training data
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_dir,
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

# Load the validation data
val_ds = tf.keras.utils.image_dataset_from_directory(
  test_dataset_dir ,
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

print("Training Classes:")
class_names = train_ds.class_names
print(class_names)

print("Testing Classes:")
class_names = val_ds.class_names
print(class_names)
# Out:
# Found 100000 files belonging to 2 classes.
# Found 20000 files belonging to 2 classes.
# Training Classes:
# ['FAKE', 'REAL']
# Testing Classes:
# ['FAKE', 'REAL']

# %% [markdown]
# Larger batch sizes are expected to result in significantly longer training times, especially with a substantial training set of 100,000 images. However, the compact size of the images effectively reduces the impact on training duration.

# %%
# Function for plotting the error rate and metrics rate
def plot_metrics(history, metric):
    plt.plot(history.history[metric], label = metric)
    plt.plot(history.history['val_' + metric], label='val_' + metric)
    plt.xlabel('Epochs')
    plt.ylabel(metric)
    plt.legend()
    plt.show()
    
# Constant values that will be shared by all the models
val_true_classes = np.concatenate([y for x, y in val_ds], axis = 0)  # Get true labels
class_names = ['FAKE', 'REAL']
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True)

# %% [markdown]
# ### Model Building
#
# All the models share the same architecture for a fair comparison: the input layer, followed by the base model with pre-trained weights from the imagenet, then a few dense layers, and then a unit output with a sigmoid activation function.
#
# Training is conducted with early stopping criteria monitoring the validation loss, and the best weights will be restored once the training is completed.

# %%
# Building the Transfer Learning model using EfficientNetV2B0
EfficientNet_base_model = tf.keras.applications.EfficientNetV2B0(
    include_top = False, 
    weights = 'imagenet', 
    input_shape = (img_height, img_width, 3),
    pooling = 'max'
)
EfficientNet_base_model.trainable = True

# Create a new model on top of the EfficientNet base
inputs = tf.keras.Input(shape = (img_height, img_width, 3))
x = EfficientNet_base_model(inputs, training = False)
x = BatchNormalization(axis = -1, momentum = 0.99, epsilon = 0.001)(x)
x = Dense(256, 
          kernel_regularizer = regularizers.l2(0.01), 
          activity_regularizer = regularizers.l1(0.01), 
          bias_regularizer = regularizers.l1(0.01),
          activation = 'relu')(x)
x = Dropout(rate = .4, seed = 512)(x)       
x = Dense(64, activation = 'relu')(x)
outputs = Dense(1, activation = 'sigmoid')(x)
EfficientNet_model = tf.keras.Model(inputs, outputs)

# Compile the Transfer Learning model
EfficientNet_model.compile(
    optimizer = tf.keras.optimizers.Adamax(learning_rate = .001),
    loss = tf.keras.losses.BinaryCrossentropy(),
    metrics = ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

# Build the Transfer Learning model so we can see a summary
EfficientNet_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b0_notop.h5
# 24274472/24274472 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)           │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ efficientnetv2-b0 (Functional)       │ (None, 1280)                │       5,919,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 1280)                │           5,120 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 256)                 │         327,936 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 6,268,881 (23.91 MB)
#  Trainable params: 6,205,713 (23.67 MB)
#  Non-trainable params: 63,168 (246.75 KB)

# %%
# Finally, train the Transfer Learning model
print("Starting training with Transfer Learning using EfficientNet...")
EfficientNet_model_history = EfficientNet_model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 20,
    verbose = 1,
    callbacks = [early_stopping]
)
print("Transfer Learning training finished.")
# Out:
# Starting training with Transfer Learning using EfficientNet...
# Epoch 1/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 602s 3s/step - accuracy: 0.4980 - loss: 3.8436 - precision_2: 0.4762 - recall_2: 0.3735 - val_accuracy: 0.5013 - val_loss: 3.7527 - val_precision_2: 0.5007 - val_recall_2: 0.9966
# Epoch 2/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 466s 2s/step - accuracy: 0.4978 - loss: 3.7207 - precision_2: 0.4981 - recall_2: 0.5609 - val_accuracy: 0.5010 - val_loss: 3.6154 - val_precision_2: 0.5005 - val_recall_2: 0.9991
# Epoch 3/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 466s 2s/step - accuracy: 0.4959 - loss: 3.5784 - precision_2: 0.4963 - recall_2: 0.5683 - val_accuracy: 0.5000 - val_loss: 3.4567 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 467s 2s/step - accuracy: 0.4996 - loss: 3.4134 - precision_2: 0.4600 - recall_2: 0.4294 - val_accuracy: 0.5002 - val_loss: 3.2754 - val_precision_2: 0.5001 - val_recall_2: 0.9995
# Epoch 5/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 468s 2s/step - accuracy: 0.5012 - loss: 3.2261 - precision_2: 0.5008 - recall_2: 0.7028 - val_accuracy: 0.5004 - val_loss: 3.0706 - val_precision_2: 0.5002 - val_recall_2: 0.9998
# Epoch 6/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 468s 2s/step - accuracy: 0.5000 - loss: 3.0159 - precision_2: 0.4999 - recall_2: 0.7144 - val_accuracy: 0.4999 - val_loss: 2.8445 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 7/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 477s 2s/step - accuracy: 0.4992 - loss: 2.7861 - precision_2: 0.4970 - recall_2: 0.5734 - val_accuracy: 0.5002 - val_loss: 2.6005 - val_precision_2: 0.5001 - val_recall_2: 0.9999
# Epoch 8/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 467s 2s/step - accuracy: 0.5011 - loss: 2.5366 - precision_2: 0.5010 - recall_2: 0.7907 - val_accuracy: 0.5003 - val_loss: 2.3420 - val_precision_2: 0.5002 - val_recall_2: 0.9999
# Epoch 9/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 468s 2s/step - accuracy: 0.5001 - loss: 2.2765 - precision_2: 0.4998 - recall_2: 0.6671 - val_accuracy: 0.5003 - val_loss: 2.0846 - val_precision_2: 0.5002 - val_recall_2: 0.9994
# Epoch 10/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 484s 2s/step - accuracy: 0.5004 - loss: 2.0229 - precision_2: 0.5000 - recall_2: 0.6929 - val_accuracy: 0.5000 - val_loss: 1.8452 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 11/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 484s 2s/step - accuracy: 0.4992 - loss: 1.7903 - precision_2: 0.4953 - recall_2: 0.6711 - val_accuracy: 0.5005 - val_loss: 1.6318 - val_precision_2: 0.5002 - val_recall_2: 0.9999
# Epoch 12/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 471s 2s/step - accuracy: 0.5012 - loss: 1.5880 - precision_2: 0.5010 - recall_2: 0.6427 - val_accuracy: 0.5004 - val_loss: 1.4604 - val_precision_2: 0.5002 - val_recall_2: 0.9998
# Epoch 13/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 472s 2s/step - accuracy: 0.5004 - loss: 1.4200 - precision_2: 0.5005 - recall_2: 0.8155 - val_accuracy: 0.4999 - val_loss: 1.3170 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 14/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 470s 2s/step - accuracy: 0.4978 - loss: 1.2853 - precision_2: 0.4866 - recall_2: 0.6008 - val_accuracy: 0.5007 - val_loss: 1.1993 - val_precision_2: 0.5004 - val_recall_2: 0.9999
# Epoch 15/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 500s 2s/step - accuracy: 0.5006 - loss: 1.1728 - precision_2: 0.5005 - recall_2: 0.6944 - val_accuracy: 0.5006 - val_loss: 1.1030 - val_precision_2: 0.5003 - val_recall_2: 0.9998
# Epoch 16/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 467s 2s/step - accuracy: 0.4997 - loss: 1.0825 - precision_2: 0.4994 - recall_2: 0.5406 - val_accuracy: 0.5003 - val_loss: 1.0264 - val_precision_2: 0.5002 - val_recall_2: 1.0000
# Epoch 17/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 465s 2s/step - accuracy: 0.5007 - loss: 1.0113 - precision_2: 0.5005 - recall_2: 0.7084 - val_accuracy: 0.5002 - val_loss: 0.9664 - val_precision_2: 0.5001 - val_recall_2: 1.0000
# Epoch 18/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 466s 2s/step - accuracy: 0.5018 - loss: 0.9566 - precision_2: 0.5018 - recall_2: 0.7443 - val_accuracy: 0.5000 - val_loss: 0.9192 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 19/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 475s 2s/step - accuracy: 0.4979 - loss: 0.9087 - precision_2: 0.4887 - recall_2: 0.6162 - val_accuracy: 0.4989 - val_loss: 0.8774 - val_precision_2: 0.2381 - val_recall_2: 0.0010
# Epoch 20/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 469s 2s/step - accuracy: 0.4979 - loss: 0.8690 - precision_2: 0.4975 - recall_2: 0.5088 - val_accuracy: 0.5003 - val_loss: 0.8418 - val_precision_2: 0.5002 - val_recall_2: 0.9997
# Transfer Learning training finished.

# %%
# Save the EfficientNet model
EfficientNet_model.save("EfficientNet_model.h5")
EfficientNet_model.save("EfficientNet_model_vivek.keras")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate the model on the test dataset
val_loss, val_accuracy, val_precision, val_recall = EfficientNet_model.evaluate(val_ds)
# Print the metrics
print(f"Val Loss: {val_loss:.4f}")
print(f"Val Accuracy: {val_accuracy:.4f}")
print(f"Val Precision: {val_precision:.4f}")
print(f"Val Recall: {val_recall:.4f}")
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 274ms/step - accuracy: 0.5016 - loss: 0.8418 - precision_2: 0.5015 - recall_2: 0.9996
# Val Loss: 0.8418
# Val Accuracy: 0.5003
# Val Precision: 0.5002
# Val Recall: 0.9997

# %%
# Plot error rates and metric rates
plot_metrics(EfficientNet_model_history, 'loss')
plot_metrics(EfficientNet_model_history, 'accuracy')
plot_metrics(EfficientNet_model_history, 'precision_2')
plot_metrics(EfficientNet_model_history, 'recall_2')
